# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import glob
import re

# %%
# Get all result CSV files
csv_files = glob.glob('images/tissuemnist_models/result_*.csv')

# Load and combine all CSVs
dfs = []
for file in csv_files:
    match = re.search(r'result_(.+)\.csv', file)
    

    downsampling_type = 'unknown'

    if match.group(1) == 'clean':
        downsampling_type = 'clean'
        downsampling_level = 0.0

    elif 'pix' in match.group(1):
        downsampling_type = 'pixel'
        downsampling_level = float(str(match.group(1).split('_')[1])[:-1])

    elif 'gauss' in match.group(1):
        downsampling_type = 'gaussian'
        downsampling_level = float(str(match.group(1).split('_')[1])[:-1])

    
    # Read CSV and add downsampling column
    df = pd.read_csv(file)
    df['downsampling_level'] = downsampling_level
    df['downsampling_type'] = downsampling_type
    dfs.append(df)

# Combine all dataframes
combined_df = pd.concat(dfs, ignore_index=True)
combined_df
# Out:
#           experiment  mi_score  discrete_mi  ova_mi_Class_0  ova_mi_Class_1  \
# 0            pix_28x  1.128617     0.793847        0.267248    6.383493e-02
# 1            pix_56x  0.544806     0.310286        0.108197    1.485237e-02
# 2             pix_4x  1.385869     1.022008        0.384150    2.010547e-01
# 3             pix_8x  1.347732     0.924201        0.339960    1.304352e-01
# 4     gauss_0.010000  1.474475     1.113835        0.427508    1.689240e-01
# 5    gauss_12.915500  0.158470     0.057319        0.018901    0.000000e+00
# 6     gauss_0.027826  1.484580     1.139920        0.414896    1.871144e-01
# 7   gauss_100.000000  0.010751     0.001549        0.000600    0.000000e+00
# 8            pix_14x  1.297867     1.013772        0.375915    1.276707e-01
# 9     gauss_0.077426  1.468894     1.205349        0.423802    2.158080e-01
# 10   gauss_35.938100  0.028457     0.002194        0.000015    0.000000e+00
# 11    gauss_0.215443  1.306520     0.974379        0.359106    1.524120e-01
# 12    gauss_4.641590  0.505234     0.307931        0.105363    1.110223e-16
# 13          pix_112x  0.212405     0.131335        0.045254    0.000000e+00
# 14           pix_16x  1.308882     1.009725        0.375491    1.106395e-01
# 15            pix_7x  1.450204     1.105329        0.417523    1.698528e-01
# 16    gauss_1.668100  0.776690     0.560695        0.176863    1.569173e-03
# 17    gauss_0.599484  1.136371     0.873719        0.305330    7.952340e-02
# 18            pix_2x  1.395940     1.018909        0.363854    1.911404e-01
# 19           pix_32x  1.040229     0.742401        0.265822    5.758297e-02
# 20             clean  1.461065     1.082656        0.404573    1.629509e-01
# 21          pix_224x  0.169917     0.110420        0.034421    0.000000e+00
#
#     ova_mi_Class_2  ova_mi_Class_3  ova_mi_Class_4  ova_mi_Class_5  \
# 0         0.140142        0.298919        0.171433        0.144838
# 1         0.030233        0.085428        0.040973        0.020542
# 2         0.235769        0.313031        0.242675        0.253350
# 3         0.202368        0.327835        0.174202        0.205971
# 4         0.202978        0.363935        0.311932        0.256837
# 5         0.015582        0.016773        0.014422        0.000477
# 6         0.299669        0.445021        0.330820        0.218788
# 7         0.000000        0.000000        0.000000        0.000000
# 8         0.235443        0.361963        0.243944        0.255239
# 9         0.336501        0.402305        0.363590        0.282749
# 10        0.002089        0.000000        0.000000        0.000000
# 11        0.199382        0.313275        0.308133        0.211390
# 12        0.098877        0.177901        0.049410        0.045155
# 13        0.007418        0.003584        0.004165        0.000825
# 14        0.283087        0.345575        0.241147        0.278510
# 15        0.282076        0.350509        0.318457        0.307302
# 16        0.085879        0.205454        0.187790        0.085236
# 17        0.187688        0.321145        0.236626        0.174369
# 18        0.240078        0.336489        0.225464        0.302286
# 19        0.202001        0.244850        0.146668        0.079643
# 20        0.287842        0.344357        0.296163        0.292634
# 21        0.000000        0.000000        0.000000        0.000056
#
#     ova_mi_Class_6  ...  ova_mi_continuous_Class_0  ova_mi_continuous_Class_1  \
# 0         0.300770  ...                   0.600015                   0.400757
# 1         0.136992  ...                   0.451671                   0.342490
# 2         0.380092  ...                   0.691933                   0.542343
# 3         0.320924  ...                   0.685774                   0.521450
# 4         0.411234  ...                   0.710461                   0.503790
# 5         0.006528  ...                   0.264571                   0.153446
# 6         0.433765  ...                   0.722809                   0.615126
# 7         0.001061  ...                   0.125008                   0.049462
# 8         0.372899  ...                   0.667654                   0.503308
# 9         0.418154  ...                   0.720427                   0.541285
# 10        0.000000  ...                   0.119362                   0.041985
# 11        0.327636  ...                   0.654793                   0.522008
# 12        0.059497  ...                   0.422048                   0.181975
# 13        0.084287  ...                   0.233809                   0.181474
# 14        0.362124  ...                   0.687416                   0.556084
# 15        0.414897  ...                   0.703925                   0.569285
# 16        0.072219  ...                   0.536566                   0.301335
# 17        0.294057  ...                   0.618740                   0.450689
# 18        0.351038  ...                   0.685854                   0.522592
# 19        0.269860  ...                   0.570651                   0.337998
# 20        0.412886  ...                        NaN                        NaN
# 21        0.057537  ...                   0.106036                   0.101320
#
#     ova_mi_continuous_Class_2  ova_mi_continuous_Class_3  \
# 0                    0.651667                   0.647136
# 1                    0.400360                   0.401928
# 2                    0.714575                   0.684310
# 3                    0.755922                   0.707270
# 4                    0.740034                   0.733013
# 5                    0.330289                   0.187620
# 6                    0.761702                   0.738124
# 7                    0.148893                   0.087075
# 8                    0.721908                   0.707092
# 9                    0.744734                   0.747060
# 10                   0.189874                   0.076418
# 11                   0.724076                   0.707710
# 12                   0.511402                   0.427687
# 13                   0.318927                   0.140914
# 14                   0.725589                   0.675652
# 15                   0.736988                   0.731880
# 16                   0.664314                   0.592040
# 17                   0.696519                   0.697284
# 18                   0.727343                   0.705356
# 19                   0.644974                   0.608077
# 20                        NaN                        NaN
# 21                   0.182399                   0.077087
#
#     ova_mi_continuous_Class_4  ova_mi_continuous_Class_5  \
# 0                    0.607469                   0.541426
# 1                    0.436988                   0.309019
# 2                    0.629905                   0.706544
# 3                    0.664753                   0.663385
# 4                    0.670648                   0.699262
# 5                    0.223371                   0.117667
# 6                    0.680017                   0.694933
# 7                    0.145488                   0.074231
# 8                    0.665280                   0.658624
# 9                    0.679739                   0.704575
# 10                   0.127024                   0.049084
# 11                   0.682620                   0.658977
# 12                   0.405281                   0.241167
# 13                   0.186765                   0.105227
# 14                   0.668306                   0.644404
# 15                   0.664200                   0.690880
# 16                   0.552757                   0.436376
# 17                   0.632468                   0.607568
# 18                   0.675702                   0.656011
# 19                   0.577542                   0.523986
# 20                        NaN                        NaN
# 21                   0.043137                   0.066272
#
#     ova_mi_continuous_Class_6  ova_mi_continuous_Class_7  downsampling_level  \
# 0                    0.586507                   0.564999            28.00000
# 1                    0.475754                   0.411454            56.00000
# 2                    0.685777                   0.656478             4.00000
# 3                    0.643876                   0.656769             8.00000
# 4                    0.692496                   0.640524             0.01000
# 5                    0.267226                   0.221048            12.91550
# 6                    0.686409                   0.690475             0.02782
# 7                    0.112278                   0.137798           100.00000
# 8                    0.636138                   0.629985            14.00000
# 9                    0.670198                   0.659269             0.07742
# 10                   0.143333                   0.105398            35.93810
# 11                   0.638350                   0.611670             0.21544
# 12                   0.397649                   0.314714             4.64159
# 13                   0.268277                   0.220130           112.00000
# 14                   0.663089                   0.640704            16.00000
# 15                   0.674420                   0.651520             7.00000
# 16                   0.499536                   0.448221             1.66810
# 17                   0.587077                   0.565606             0.59948
# 18                   0.667380                   0.660169             2.00000
# 19                   0.576158                   0.535228            32.00000
# 20                        NaN                        NaN             0.00000
# 21                   0.159186                   0.105301           224.00000
#
#     downsampling_type
# 0               pixel
# 1               pixel
# 2               pixel
# 3               pixel
# 4            gaussian
# 5            gaussian
# 6            gaussian
# 7            gaussian
# 8               pixel
# 9            gaussian
# 10           gaussian
# 11           gaussian
# 12           gaussian
# 13              pixel
# 14              pixel
# 15              pixel
# 16           gaussian
# 17           gaussian
# 18              pixel
# 19              pixel
# 20              clean
# 21              pixel
#
# [22 rows x 21 columns]

# %%
import numpy as np
from lmfit import Model

def info_scaling(x, A, B):
    return 0.5 * np.log2(((x)*B + 1)/(1 + A*(x)))

# Prepare data for pixel downsampling
pix = combined_df[combined_df['downsampling_type'] == 'pixel'].copy()
pix['inv_factor'] = 1 / pix['downsampling_level']

# Get OVA MI columns
ova_columns = ['mi_score', 'discrete_mi'] + [col for col in pix.columns if col.startswith('ova_mi_continuous_Class_')]
n_classes = len(ova_columns)

# Create label mapping for prettier names
label_map = {
    'ova_mi_Class_0': 'Class 0',
    'ova_mi_Class_1': 'Class 1', 
    'ova_mi_Class_2': 'Class 2',
    'ova_mi_Class_3': 'Class 3',
    'ova_mi_Class_4': 'Class 4',
    'ova_mi_Class_5': 'Class 5',
    'ova_mi_Class_6': 'Class 6',
    'ova_mi_Class_7': 'Class 7',
    'mi_score': 'Last layer MI',
    'discrete_mi': 'Discrete MI'
}

# Create figure
fig = plt.figure(figsize=(4, 3), dpi=150)

# Generate color palette
palette = sns.color_palette("hls", n_classes)

# Fit and plot each class
for i, col in enumerate(ova_columns[::-1]):
    # Prepare data (remove any NaN values)
    mask = ~pix[col].isna() & ~pix['inv_factor'].isna()
    x_data = pix[mask]['inv_factor'].values**2
    y_data = pix[mask][col].values
    

    # Create model and parameters
    model = Model(info_scaling)
    params = model.make_params(A=1e3, B=1e3)
    params['A'].min = 0
    params['B'].min = 0
    
    try:
        # Fit model
        result = model.fit(y_data, params, x=x_data)
        print(result.params)
        
        # Generate fit line
        x_fit = np.logspace(np.log10(x_data.min()/5), np.log10(5*x_data.max()), 10**5)
        y_fit = model.eval(params=result.params, x=x_fit)
        
        # Calculate confidence bands
        y_upper = result.eval_uncertainty(params=result.params, x=x_fit, sigma=2)
        y_lower = -y_upper
        
        # Plot fit
        plt.plot(x_fit, y_fit, linestyle='--', color=palette[i], alpha=0.5)
        plt.fill_between(x_fit, y_fit + y_upper, y_fit + y_lower, 
                        color=palette[i], alpha=0.2)
    except:
        pass  # Skip if fit fails
    
    # Plot data
    plt.scatter(x_data, y_data, color=palette[i], 
               label=label_map.get(col, col), s=30)

plt.xlabel(r'$1/\text{downsampling factor}$')
plt.ylabel(r'$I(L; \hat{L})$')
plt.xscale('log')
# plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=8)
plt.tight_layout()
plt.show()
# Out:
# Parameters([('A', <Parameter 'A', value=3664.2900263678157 +/- 294, bounds=[0:inf]>), ('B', <Parameter 'B', value=9096.634372185688 +/- 687, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=5652.82324785888 +/- 707, bounds=[0:inf]>), ('B', <Parameter 'B', value=14165.339454451474 +/- 1.68e+03, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=1704.8969312926724 +/- 166, bounds=[0:inf]>), ('B', <Parameter 'B', value=4464.90644297489 +/- 400, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=3417.1271315250106 +/- 356, bounds=[0:inf]>), ('B', <Parameter 'B', value=8729.624905400036 +/- 855, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=2549.3356261637823 +/- 317, bounds=[0:inf]>), ('B', <Parameter 'B', value=6962.614510269972 +/- 803, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=4321.791567224269 +/- 989, bounds=[0:inf]>), ('B', <Parameter 'B', value=11938.120336873002 +/- 2.56e+03, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=3216.6630162467645 +/- 955, bounds=[0:inf]>), ('B', <Parameter 'B', value=6714.911258605453 +/- 1.89e+03, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=3766.4930402887694 +/- 283, bounds=[0:inf]>), ('B', <Parameter 'B', value=9853.072826505151 +/- 695, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=962.9998757011892 +/- 207, bounds=[0:inf]>), ('B', <Parameter 'B', value=4216.156785095888 +/- 787, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=919.9613026417622 +/- 131, bounds=[0:inf]>), ('B', <Parameter 'B', value=6668.938106448282 +/- 793, bounds=[0:inf]>)])

# %%
import numpy as np
from lmfit import Model

def info_scaling(x, A, B):
    return 0.5 * np.log2(((x)*B + 1)/(1 + A*(x)))

# Prepare data for gaussian downsampling
gauss = combined_df[combined_df['downsampling_type'] == 'gaussian'].copy()

# Get OVA MI columns
ova_columns = [col for col in gauss.columns if col.startswith('ova_mi_continuous_Class_')] + ['mi_score', 'discrete_mi']
n_classes = len(ova_columns)


# Create figure
fig = plt.figure(figsize=(4, 3), dpi=150)

# Generate color palette
palette = sns.color_palette("hls", n_classes)

# Fit and plot each class
for i, col in enumerate(ova_columns[::-1]):
    # Prepare data (remove any NaN values)
    mask = ~gauss[col].isna()
    x_data = 1/gauss[mask]['downsampling_level'].values
    y_data = gauss[mask][col].values
    

    # Create model and parameters
    model = Model(info_scaling)
    params = model.make_params(A=1e-3, B=1e-3)
    params['A'].min = 0
    params['B'].min = 0
    
    try:
        # Fit model
        result = model.fit(y_data, params, x=x_data)
        print(result.params)
        
        # Generate fit line
        x_fit = np.logspace(np.log10(x_data.min()/5), np.log10(5*x_data.max()), 10**5)
        y_fit = model.eval(params=result.params, x=x_fit)
        
        # Calculate confidence bands
        y_upper = result.eval_uncertainty(params=result.params, x=x_fit, sigma=2)
        y_lower = -y_upper
        
        # Plot fit
        plt.plot(x_fit, y_fit, linestyle='--', color=palette[i], alpha=0.5)
        plt.fill_between(x_fit, y_fit + y_upper, y_fit + y_lower, 
                        color=palette[i], alpha=0.2)
    except:
        pass  # Skip if fit fails
    
    # Plot data
    plt.scatter(x_data, y_data, color=palette[i], 
               label=label_map.get(col, col), s=30)

plt.xlabel(r'$1/\text{variance}$')
plt.ylabel(r'$I(L; \hat{L})$')
plt.xscale('log')
# plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=8)
plt.tight_layout()
plt.show()
# Out:
# Parameters([('A', <Parameter 'A', value=0.6617119679708914 +/- 0.106, bounds=[0:inf]>), ('B', <Parameter 'B', value=3.3864849459109516 +/- 0.452, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=0.6531792402567236 +/- 0.0601, bounds=[0:inf]>), ('B', <Parameter 'B', value=5.280025028259293 +/- 0.389, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=3.198922030226588 +/- 0.701, bounds=[0:inf]>), ('B', <Parameter 'B', value=7.900175361076039 +/- 1.6, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=4.828497640072711 +/- 0.752, bounds=[0:inf]>), ('B', <Parameter 'B', value=12.143395307584257 +/- 1.76, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=1.610898198167837 +/- 0.171, bounds=[0:inf]>), ('B', <Parameter 'B', value=4.339902565847205 +/- 0.418, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=4.516623342349493 +/- 0.733, bounds=[0:inf]>), ('B', <Parameter 'B', value=11.665514695522388 +/- 1.75, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=3.308641385079186 +/- 0.378, bounds=[0:inf]>), ('B', <Parameter 'B', value=9.362846280848766 +/- 0.978, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=6.867697596590336 +/- 0.78, bounds=[0:inf]>), ('B', <Parameter 'B', value=19.30980753602628 +/- 2.03, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=1.6732124763564342 +/- 0.375, bounds=[0:inf]>), ('B', <Parameter 'B', value=3.6389239497530985 +/- 0.755, bounds=[0:inf]>)])
# Parameters([('A', <Parameter 'A', value=4.4486428144742876 +/- 0.666, bounds=[0:inf]>), ('B', <Parameter 'B', value=11.745184437568735 +/- 1.62, bounds=[0:inf]>)])
